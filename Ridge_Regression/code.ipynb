# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from sklearn.datasets import load_diabetes

x,y = load_diabetes(return_X_y=True)

# %%
x.shape
# Out:
# (442, 10)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y)

# %%
from sklearn.linear_model import LinearRegression

# %%
LR = LinearRegression()

# %%
LR.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=LR.predict(x_test)

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test,y_pred)
# Out:
# 0.46124416931954926

# %%
from sklearn.linear_model import Ridge

# %%
R = Ridge(alpha=0.01)

# %%
R.fit(x_train,y_train)
# Out:
# Ridge(alpha=0.01)

# %%
y_pred=R.predict(x_test)

# %%
r2_score(y_test,y_pred)
# Out:
# 0.46014151178049656

# %%
x = 6 * np.random.rand(200,1)-3
y = 0.8 * x**2 + 0.9*x + 2 + np.random.randn(200,1)

# %%
plt.scatter(x,y)

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import Ridge

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y)

# %%
model = Pipeline([
    ('poly',PolynomialFeatures(degree=10)),
    ('ridge',Ridge(alpha=20))
])

model2 =  Pipeline([
    ('poly',PolynomialFeatures(degree=10)),
    ('ridge',Ridge(alpha=0))
])

# %%
model.fit(x_train,y_train)
# Out:
# Pipeline(steps=[('poly', PolynomialFeatures(degree=10)),
#                 ('ridge', Ridge(alpha=20))])

# %%
model2.fit(x_train,y_train)
# Out:
# Pipeline(steps=[('poly', PolynomialFeatures(degree=10)),
#                 ('ridge', Ridge(alpha=0))])

# %%
y_pred=model.predict(x_test)

# %%
y_pred2=model2.predict(x_test)

# %%
x_new = np.linspace(x_train.min(),x_train.max(),x_train.shape[0])
x_new.shape
# Out:
# (150,)

# %%
y_new=model.predict(x_new.reshape(-1,1))
y_new2=model2.predict(x_new.reshape(-1,1))

# %%
plt.scatter(x_test,y_test)
plt.plot(x_new,y_new,color='red',label='alpha=10')
plt.plot(x_new,y_new2,color='green',label='alpha=0')
plt.legend()
