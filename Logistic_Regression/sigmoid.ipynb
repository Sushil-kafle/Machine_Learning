# %%
from sklearn.datasets import make_classification
import numpy as np
x,y = make_classification(n_samples=100
                          ,n_features=2,
                          n_classes=2,
                          n_informative=2,
                          n_redundant=0,
                          n_clusters_per_class=1,
                          hypercube=False,
                          class_sep=10,
                          random_state=30
                          )

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(x[:,0],x[:,1],c=y)

# %%
def sigmoid(n):
    return 1/(1+np.exp(-1*n))

# %%
sigmoid(100)
# Out:
# 1.0

# %%
def new_perceptron(x,y):
    x=np.insert(x,0,1,axis=1)
    weights= np.ones(x.shape[1])
    lr =0.01
    epoch =100000

    for j in range(epoch):
        j = np.random.randint(0,y.size)
        y_hat = sigmoid(np.dot(x[j],weights))
        weights = weights + lr * (y[j]-y_hat)*x[j]

    return weights[0],weights[1:]

# %%
intercept_,coefficient_=new_perceptron(x,y)
intercept_,coefficient_
# Out:
# (0.4352489402976161, array([5.85320324, 0.9743988 ]))

# %%
m = -1*( coefficient_[0]/coefficient_[1])
b = -1*(intercept_/coefficient_[1])

# %%
plt.figure(figsize=(10,8))
plt.scatter(x[:,0],x[:,1],c=y)
x_new = np.linspace(np.min(x),np.max(x),x.shape[0])
y_new = m*x_new+b
plt.plot(x_new,y_new)
